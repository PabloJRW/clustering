# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloJRW/clustering/blob/main/hierachical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %% [markdown]
# ## Generando los datos

# %%
X, y, c = make_blobs(500, 
                     cluster_std=0.8,
                     centers=4,
                     n_features=2,
                     return_centers=True, 
                     random_state=10)

df = pd.DataFrame({
    'x1': X[:,0],
    'x2': X[:,1],
    'y' : y
})

df_centers = pd.DataFrame({
    'x1': c[:,0],
    'x2': c[:,1]
})

# %% [markdown]
# ## Visualización de datos

# %%
sns.scatterplot(data=df, x='x1', y='x2')
plt.show()

# %% [markdown]
# ## Dendrograma y Hierarchical Clustering

# %%
dendro = dendrogram(linkage(X, method='ward'))
plt.title("Dendrogram - Ward Linkage")
plt.xlabel("Clusters")
plt.ylabel("Distancia Euclidiana")
plt.show()
